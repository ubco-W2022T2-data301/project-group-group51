# %% [markdown]
# # Data 301 project
# ## by Max, Ken,

# %% [markdown]
# ## Following is the airline codes
# |#| Code | Airline |
# |-----:|:------|:--------------|
# |1|9E| Endeavor Air Inc.|
# |2|AA| American Airlines Inc. |
# |3|AS| Alaska Airlines Inc.|
# |4|B6| JetBlue Airways|
# |5|DL| Delta Air Lines Inc.|
# |6|EV| ExpressJet Airlines Inc.|
# |7|F9| Frontier Airlines Inc.|
# |8|G4| Allegiant Air|
# |9|HA| Hawaiian Airlines Inc.|
# |10|MQ| Envoy Air|
# |11|NK| Spirit Air Lines|
# |12|OH| PSA Airlines Inc.|
# |13|OO| SkyWest Airlines Inc.|
# |14|QX| Horizon Air|
# |15|UA| United Airlines Inc.|
# |16|WN| Southwest Airlines Co.|
# |17|YV|Mesa Airlines Inc.|
# |18|YX|Republic Airline|

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

#sample_data = pd.read_csv('airline.csv')
airlineDatajan2021Dec2021 = pd.read_csv('../data/raw/Airline_Data_Jan2021-Dec2021.csv')
#we can changes this file above just ensure naming is somewhat descriptive cause this could get messy
airlineDatajan2021Dec2021
# Out:
#        year  month carrier       carrier_name airport  \
# 0      2021     12      9E  Endeavor Air Inc.     ABE
# 1      2021     12      9E  Endeavor Air Inc.     ABY
# 2      2021     12      9E  Endeavor Air Inc.     AEX
# 3      2021     12      9E  Endeavor Air Inc.     AGS
# 4      2021     12      9E  Endeavor Air Inc.     ALB
# ...     ...    ...     ...                ...     ...
# 19949  2021      1      YX   Republic Airline     TLH
# 19950  2021      1      YX   Republic Airline     TPA
# 19951  2021      1      YX   Republic Airline     TUS
# 19952  2021      1      YX   Republic Airline     TVC
# 19953  2021      1      YX   Republic Airline     VPS
#
#                                             airport_name  arr_flights  \
# 0      Allentown/Bethlehem/Easton, PA: Lehigh Valley ...        127.0
# 1                 Albany, GA: Southwest Georgia Regional         73.0
# 2               Alexandria, LA: Alexandria International         62.0
# ...

# %%
import numpy as np

flights = airlineDatajan2021Dec2021["arr_flights"].sum()
delayed15 = airlineDatajan2021Dec2021["arr_del15"].sum()
late = airlineDatajan2021Dec2021["late_aircraft_ct"].sum()
cancelled = airlineDatajan2021Dec2021["arr_cancelled"].sum()
diverted = airlineDatajan2021Dec2021["arr_diverted"].sum()
arrivaldelayed = airlineDatajan2021Dec2021["arr_delay"].sum()
carrierdelay = airlineDatajan2021Dec2021["carrier_delay"].sum()
weather = airlineDatajan2021Dec2021["weather_delay"].sum()

#, 'diverted', 'arrivaldelayed', 'carrierdelay', 'Weather'
var = np.array([flights, delayed15, late, cancelled, diverted, arrivaldelayed, carrierdelay, weather])

labels = ['Flights', 'Delayed > 15', 'Late', 'Arrival cancelled', 'Diverted', 'Arrival delayed', 'Carrier delay', 'Weather delay']
#autopct = '%.1f%%'
# diverted, arrivaldelayed, carrierdelay, weather
plt.pie(var, startangle = 90)
plt.legend(labels, title = "Legend",bbox_to_anchor = (1.05,1), loc = "best")
plt.show()

# %%
plt.bar(airlineDatajan2021Dec2021.carrier, airlineDatajan2021Dec2021.arr_cancelled)
plt.xlabel('Carrier Code:')
plt.ylabel('Number of flights Canceled')
plt.title('Number Of flights cancelled from Jan 2022 to Oct 2022')
plt.show()

# %%
plt.bar(airlineDatajan2021Dec2021.carrier, airlineDatajan2021Dec2021.arr_del15)
plt.title('Number of Flights Delayed 15 Mins or more')
plt.xlabel('Carrier Code:')
plt.ylabel('Number of flights Delayed')
plt.show()

# %%
plt.bar(airlineDatajan2021Dec2021.carrier, airlineDatajan2021Dec2021.weather_delay)
plt.xlabel('Carrier Code:')
plt.ylabel('Number of Weather delays')
plt.title('Weather delay bar chart')
plt.show()

# %%
plt.bar(airlineDatajan2021Dec2021.carrier, airlineDatajan2021Dec2021.security_delay)
plt.title('Security delays')
plt.xlabel('Carrier Code:')
plt.ylabel('Number of delays')
plt.show()

# %%
plt.bar(airlineDatajan2021Dec2021.carrier, airlineDatajan2021Dec2021.late_aircraft_delay)
plt.title('Late aircraft delays')
plt.xlabel('Carrier Code:')
plt.ylabel('Number of late aircraft')
plt.show()

# %%
#plt.hexbin(airlineDatajan2021Dec2021.security_delay, airlineDatajan2021Dec2021.weather_delay, color = "green")

# %%
#cause of delay
plot = sns.catplot(data = airlineDatajan2021Dec2021, x=airlineDatajan2021Dec2021.carrier, y = airlineDatajan2021Dec2021.arr_del15, kind = "violin")
#sns.swarmplot(data = airlineDatajan2021Dec2021)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 2
#       1 #cause of delay
# ----> 2 plot = sns.catplot(data = airlineDatajan2021Dec2021, x=airlineDatajan2021Dec2021.carrier, y = airlineDatajan2021Dec2021.arr_del15, kind = "violin")
#       3 #sns.swarmplot(data = airlineDatajan2021Dec2021)
#
# File ~\miniconda3\lib\site-packages\seaborn\categorical.py:3244, in catplot(data, x, y, hue, row, col, col_wrap, estimator, errorbar, n_boot, units, seed, order, hue_order, row_order, col_order, height, aspect, kind, native_scale, formatter, orient, color, palette, hue_norm, legend, legend_out, sharex, sharey, margin_titles, facet_kws, ci, **kwargs)
#    3241 g = FacetGrid(**facet_kws)
#    3243 # Draw the plot onto the facets
# -> 3244 g.map_dataframe(plot_func, x=x, y=y, hue=hue, **plot_kws)
#    3246 if p.orient == "h":
# ...

# %% [markdown]
# ## End
